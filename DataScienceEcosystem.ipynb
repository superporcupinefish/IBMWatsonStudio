# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystems are summarized. And whatever else they tell me to write :D.

# %% [markdown]
# **Objectives of this notebook:**
# - fullfill all of the exercise requirements (to be honest)
# - list common languages used in data science
# - list common libraries used in data science
# - name a few open IDEs used in data scince

# %% [markdown]
# **Here are examples of the most common languages used by Data Sciences:**
#
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# **Here are some common libraries these languages might use:**
#
# 1. Pandas (data management in Python)
# 2. ggplot (plotting and visualization in R)
# 3. NumPy (adds additional mathmatical functions to Python)
# 4. Matplotlib (plotting and visualization in python)

# %% [markdown]
# **Data Science Tools Table**
#
# |Data Science Tools |
# |------|
# |Rstduio|
# |JupyterLab|
# |Anaconda|
# |Spyder|

# %% [markdown]
# ### Below are example of arithmetic expressions in Python

# %%
# This is a simple arithmetic expression to multiply then add integers.
(3*4)+5
# Out:
# 17

# %%
#This cell converts 200 minutes into hours
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Amie Corbin
